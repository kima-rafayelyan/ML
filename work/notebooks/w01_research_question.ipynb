# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kima-rafayelyan/ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# My lane: Refresh / Content Opportunity Scoring
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on a practical content management problem: identifying which pages should be reviewed first for possible improvement.
#
# Large content collections may contain thousands of pages, and manually reviewing every page is inefficient. This project aims to create a transparent scoring approach that helps prioritize pages for actions such as refresh, expansion, protection, monitoring, or pruning.
#
# I chose this lane because it connects data analysis and machine learning with a real decision: helping content teams decide where their time and resources should be invested. The goal is not to guarantee traffic growth, but to identify pages with performance patterns that suggest they may deserve further review.

# %%
print("Lane: Refresh / Content Opportunity Scoring")
print("Goal: Rank pages for content review based on observed performance signals.")
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Goal: Rank pages for content review based on observed performance signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## Research Question
#
# Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring based on their historical performance signals?
#
# ### Decision
#
# This work supports the decision of which pages should receive attention from a content or SEO team first.
#
# ### Who acts on it?
#
# Content managers, SEO specialists, or editors can use the ranked opportunity list to decide which pages require review and what type of action may be appropriate.
#
# ### Action
#
# The output can suggest actions such as:
#
# - Refresh outdated pages
# - Expand pages with growth potential
# - Protect pages that already perform well
# - Monitor stable pages
# - Consider pruning low-value pages
#
# ### Cost of a wrong recommendation
#
# A wrong recommendation may cause the team to spend time and resources improving pages that have limited potential, while more valuable opportunities are missed.
#
# The system provides decision support, not guaranteed outcomes.

# %%
actions = [
    "Refresh",
    "Expansion",
    "Protection",
    "Monitoring",
    "Pruning"
]

print("Possible recommended actions:")
for action in actions:
    print("-", action)
# Out:
# Possible recommended actions:
# - Refresh
# - Expansion
# - Protection
# - Monitoring
# - Pruning

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
#
# I used the `content_refresh_anonymized.csv` starter dataset, which contains anonymized content performance data from Google Search Console and GA4 signals.
#
# Initial exploration shows:
#
# - 30,000 content pages are included in the dataset.
# - The average number of impressions per page is 5200.
# - The average CTR across pages is 0.51%.
#
# These measurements show that the dataset contains visibility and engagement signals that can help identify pages with potential refresh or improvement opportunities.
#
# The goal is not to determine which pages will definitely improve, but to rank pages that deserve further review based on observed performance patterns.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("content_refresh_anonymized.csv")

# Dataset size
print("Dataset shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

# Basic statistics
print("\nDataset preview:")
display(df.head())
# Out:
# Dataset shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# Dataset preview:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %%
print("Number of pages:", len(df))

numeric_summary = df.select_dtypes(include="number").describe().T

display(numeric_summary.head(10))
# Out:
# Number of pages: 30000
#                    count          mean           std   min      25%      50%  \
# search_volume    27532.0    158.882391   1518.270825   0.0      0.0     10.0
# competition      27532.0      0.146954      0.285241   0.0      0.0      0.0
# cpc              27532.0      0.485342      2.101560   0.0      0.0      0.0
# word_count       22301.0   3107.760325   1452.382598   8.0   2413.0   2877.0
# char_count       22301.0  20665.277835  10115.344042  40.0  15644.0  19116.0
# impressions_90d  30000.0   5200.366300  16838.019547   1.0     81.0    731.0
# clicks_90d       30000.0     16.097333     75.076958   0.0      0.0      1.0
# pageviews_90d    30000.0     49.942467    152.101430   0.0      2.0      8.0
# sessions_90d     30000.0     37.066633    107.069131   1.0      2.0      7.0
# users_90d        30000.0     35.937700    103.748185   1.0      2.0      7.0
#
#                       75%        max
# search_volume       20.00   74000.00
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
#
# ## What I can and cannot claim
#
# This project can identify pages with performance patterns that are associated with potential improvement opportunities.
#
# The analysis can provide directional recommendations and decision support for content teams.
#
# However, it cannot prove that refreshing a page will definitely increase traffic, rankings, or engagement because this is observational data and not a controlled experiment.
#
# The model cannot predict or explain Google's ranking algorithm. It only analyzes patterns observed in the available dataset.

# %%
claims = {
    "observed": True,
    "directional": True,
    "decision_support": True,
    "causal_proof": False,
    "predict_google_rankings": False
}

for key, value in claims.items():
    print(f"{key}: {value}")
# Out:
# observed: True
# directional: True
# decision_support: True
# causal_proof: False
# predict_google_rankings: False

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
